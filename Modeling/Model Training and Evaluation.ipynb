# %%
# Kalo belom ada librarynya

# !pip install ultralytics IPython

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.train(data='data.yaml', epochs=50, imgsz=320, batch=32, device=0)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.234 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.222  Python-3.10.18 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs\detect\\train2\\weights\\best.pt")

results = model.predict(
    source="test/images",
    imgsz=320,
    project="runs/detect",
    name="TestPredictions",
    save=True
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1619 c:\Users\justi\Documents\Project\SoCS\Python\Deep Learning Project BENERAN!\test\images\2-Jari_mp4-0017_jpg.rf.699c9e0166de0be22915462ace3b58fa.jpg: 192x320 1 Two, 11.0ms
# image 2/1619 c:\Users\justi\Documents\Project\SoCS\Python\Deep Learning Project BENERAN!\test\images\2-Jari_mp4-0019_jpg.rf.e618c8ad83c5388a0cbdf7ae79b717bf.jpg: 192x320 1 Two, 10.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for ImagePath in glob.glob('runs/detect/TestPredictions/*.jpg')[:100] :
    display(Image(filename=ImagePath, height = 400))
    print('\n')
